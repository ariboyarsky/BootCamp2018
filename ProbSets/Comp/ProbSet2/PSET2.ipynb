# %% [markdown]
# # PSet2
# # Ari Boyarsky

# %%
# Intro to Matplotlib
# 1

# %%
import numpy as np
from matplotlib import pyplot as plt
from datetime import datetime
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from datetime import datetime
import itertools as it

n = 6
arr = np.random.normal(size=(2,3))
print(np.mean(arr,0))
print(np.var(arr, 0))
# Out:
# [-0.88994981  0.4766962  -0.65632368]
# [ 0.08387514  0.27923834  1.10950731]

# %%
def plot_1(mr, vr):
    plt.plot(mr, vr)
    plt.show()

plot_1(np.mean(arr,0), np.var(arr,0))

# %%
# 2
x = np.linspace(-2*np.pi,2*np.pi,100);
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.arctan(x)

# %%
plt.plot(x, y1, x, y2, x, y3)
plt.show()

# %%
# 3
x_1 = np.linspace(-2,1)
x_2 = np.linspace(1,6)
def f(x):
    return (1/(x-1))
f1=f(x_1)
f2=f(x_2)
plt.plot(x_1, f1, x_2, f2)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
#4
x = np.linspace(-2*np.pi, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.sin(2*x)
y3 = 2*np.sin(x)
y4 = 2*np.sin(2*x)

ax1 = plt.subplot(2,2,1)
ax1.plot(x, y1)
ax2 = plt.subplot(2,2,2)
ax2.plot(x, y2)
ax3 = plt.subplot(2,2,3)
ax3.plot(x, y3)
ax4 = plt.subplot(2,2,4)
ax4.plot(x, y4)

plt.show()

# %%
# 5
def prob_1_5():
    dta = np.load("FARS.npy")
    ax1 = plt.subplot(2,2,1)
    ax1.scatter(dta[:,1], dta[:,2])
    ax1.set_xlabel("Long")
    ax1.set_ylabel("Lat")
    ax2 = plt.subplot(2,2,2)
    ax2.hist(dta[:,0])
    ax2.set_xlabel("Hrs")
    plt.show()

# %%
prob_1_5()

# %%
# 6
x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = x.copy()
X, Y = np.meshgrid(x, y)

def g(x,y):
    num = np.sin(x)*np.sin(y)
    denom = x*y
    return num/denom

Z = g(X,Y)

plt.subplot(121)
plt.pcolormesh(X, Y, Z, cmap="viridis")
plt.colorbar()
plt.xlim(-np.pi, np.pi)
plt.ylim(-np.pi, np.pi)

plt.subplot(122)
plt.contour(X, Y, Z, 10, cmap="coolwarm")
plt.colorbar()
plt.show()

# %%
# Data Vis

# %%
# 1
dta = np.load("anscombe.npy")
plt.scatter(dta[:,0], dta[:,1])
plt.show()

# %%
from scipy import stats
stats.linregress(dta[:,0],dta[:,1])
# Out:
# LinregressResult(slope=0.50009090909090914, intercept=3.0000909090909103, rvalue=0.81642051634483992, pvalue=0.0021696288730787901, stderr=0.11790550059563408)

# %%
plt.scatter(dta[:,0], dta[:,1])
x = np.linspace(0,20)
y = 3+0.5*x
plt.plot(x,y)
plt.show()

# %%
print(np.mean(dta[:,0]), np.mean(dta[:,1]), np.var(dta[:,0]), np.var(dta[:,1]))
# Out:
# 9.0 7.50090909091 10.0 3.75206280992

# %%
# 2
from scipy import special

fig, axs = plt.subplots(1,10, figsize=(15, 6))
fig.subplots_adjust(hspace = .5, wspace=.001)

axs = axs.ravel()

x = np.linspace(0,100,200)
def b(x):
    i = 0
    for n in range(0,4):
        for v in range(0,n+1):
            y = special.binom(n, v)*(x**v)*(1-x)**(n-v)
            axs[i].plot(x,y)
            ttl = "n="+str(n)+" v="+str(v)
            axs[i].set_title(ttl)
            i+=1
b(x)
plt.show()

# %%
# 3
dta = np.load("MLB.npy")
plt.scatter(dta[:,0], dta[:,1])
plt.show()

# %%
plt.scatter(dta[:,1], dta[:,2])
plt.show()

# %%
plt.scatter(dta[:,0], dta[:,2])
plt.show()

# %%
plt.scatter(dta[:,0], dta[:,2])
stats.linregress(dta[:,0], dta[:,2])
x=np.linspace(50,100)
y = 38+(-0.138)*x
plt.plot(x,y)
plt.show()

# %%
# 4 
year, magnitude, longitude, latitude = np.load("earthquakes.npy").T

# %%
# 1. how many earthquakes happen per year?
from itertools import groupby
year = [int(x) for x in year]

# %%
nums = [len(list(group)) for key, group in groupby(year)]
np.mean(nums)
# Out:
# 1706.5

# %%
plt.hist(year)
plt.hlines(1706.5,2000,2010)
plt.show()

# %%
#2. How often do stronger quakes happen comapred to weaker ones?
plt.hist(magnitude)
plt.show()

# %%
# 3. Where do quakes happen? Answer around plate boundries.
plt.scatter(longitude, latitude, cmap = "inferno", c = magnitude,)
plt.colorbar()
plt.axis("equal")
plt.show()

# %%
# 5
def f(x,y):
    return (1-x)**2 + 100*(y-x**2)**2

x = np.linspace(-10, 10, 100)
y = x.copy()
X, Y = np.meshgrid(x, y)
Z = f(X,Y)

plt.contour(X, Y, Z, 10, cmap="magma")
plt.show()

# %%
# 6
dta = np.load("countries.npy")
plt.scatter(dta[:,0], dta[:,1])
plt.show()

# %%
plt.scatter(dta[:,0], dta[:,2])
plt.show()

# %%
plt.scatter(dta[:,0], dta[:,3])
plt.show()

# %%
plt.scatter(dta[:,2], dta[:,3])
plt.show()

# %%
# Pandas 1
# 1
import pandas as pd
x = list(range(0,50,2))
y = [n**2-1 for n in x]  
s = pd.Series(y, index=range(0,50,2))

# %%
# 2

# %%
def walk(prob, d=100):
    days = pd.date_range("1/1/2000", "12/31/2000", freq='D')
    s = np.zeros(len(days))
    s[0] = d
    c = [1,-1]
    for i in range(1, len(days)):
        s[i] = s[i-1] + np.random.choice(c, p = [prob, 1-prob])
    return(pd.Series(s, index=days))

# %%
plt.plot(walk(0.5))
plt.show()

# %%
plt.plot(walk(0.2, 200))
plt.show()

# %%
plt.plot(walk(0.9, 20))
plt.show()

# %%
plt.plot(walk(0.65, 100))
plt.show()

# %%
# 3
name = ['Mylan', 'Regan', 'Justin', 'Jess', 'Jason', 'Remi', 'Matt', 'Alexander', 'JeanMarie']
sex = ['M', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'F']
age = [20, 21, 18, 22, 19, 20, 20, 19, 20]
rank = ['Sp', 'Se', 'Fr', 'Se', 'Sp', 'J', 'J', 'J', 'Se']
ID = range(9)
aid = ['y', 'n', 'n', 'y', 'n', 'n', 'n', 'y', 'n']
GPA = [3.8, 3.5, 3.0, 3.9, 2.8, 2.9, 3.8, 3.4, 3.7]
mathID = [0, 1, 5, 6, 3]
mathGd = [4.0, 3.0, 3.5, 3.0, 4.0]
major = ['y', 'n', 'y', 'n', 'n']
studentInfo = pd.DataFrame({'ID': ID, 'Name': name, 'Sex': sex, 'Age': age, 'Class': rank})
otherInfo = pd.DataFrame({'ID': ID, 'GPA': GPA, 'Financial_Aid': aid})
mathInfo = pd.DataFrame({'ID': mathID, 'Grade': mathGd, 'Math_Major': major})

# %%
studentInfo.query("Age > 19 & Sex == 'M'")[["ID", "Name"]]
# Out:
#    ID   Name
# 0   0  Mylan
# 6   6   Matt

# %%
# 4
pd.merge(studentInfo, otherInfo, on="ID")
# Out:
#    Age Class  ID       Name Sex Financial_Aid  GPA
# 0   20    Sp   0      Mylan   M             y  3.8
# 1   21    Se   1      Regan   F             n  3.5
# 2   18    Fr   2     Justin   M             n  3.0
# 3   22    Se   3       Jess   F             y  3.9
# 4   19    Sp   4      Jason   M             n  2.8
# 5   20     J   5       Remi   F             n  2.9
# 6   20     J   6       Matt   M             n  3.8
# 7   19     J   7  Alexander   M             y  3.4
# 8   20    Se   8  JeanMarie   F             n  3.7

# %%
# 5

dta  = pd.read_csv("crime_data.txt")
dta['crime_rate'] = dta['Total']/dta['Population']

# %%
plt.plot(dta['Year'], dta['crime_rate'])
plt.show()

# %%
dta.sort_values('crime_rate', ascending=False).head(5)[['Year','crime_rate']]
# Out:
#     Year  crime_rate
# 20  1980    0.059500
# 31  1991    0.058978
# 21  1981    0.058582
# 30  1990    0.058203
# 29  1989    0.057410

# %%
dta[dta.Year < 2013][['Total', 'Burglary']].describe()
# Out:
#               Total      Burglary
# count  5.300000e+01  5.300000e+01
# mean   1.063807e+07  2.446286e+06
# std    3.230843e+06  7.299596e+05
# min    3.384200e+06  9.121000e+05
# 25%    8.718100e+06  2.116531e+06
# 50%    1.156550e+07  2.375500e+06
# 75%    1.319457e+07  3.073900e+06
# max    1.487290e+07  3.795200e+06

# %%
dta[(dta.Total < 1.06e07) & (dta.Burglary > 2.44e06)]['Year']
# Out:
# 13    1973
# 14    1974
# Name: Year, dtype: int64

# %%
plt.plot(dta['Population'],dta['Murder'])
plt.show()

# %%
dta2 = dta[['Population', 'Violent', 'Robbery']]
dta2.to_csv("crime_subset.csv")

# %%
# 6
# The following does not work, nor is this even a package in the anaconda repo channels
# import pydataset as data

# %%
# Pandas 2
#1
Arbuthnot = data("Arbuthnot")
Arbuthnot.plot(x = "Year", y = ['Males', 'Females'], kind = "line")
plt.title("Number of males and females born each year.")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-58a1c8675e4f> in <module>()
#       1 # Pandas 2
#       2 #1
# ----> 3 Arbuthnot = data("Arbuthnot")
#       4 Arbuthnot.plot(x = "Year", y = ['Males', 'Females'], kind = "line")
#       5 plt.title("Number of males and females born each year.")
#
# NameError: name 'data' is not defined

# %%
#4
finance = pd.read_csv("finances.csv")
per=pd.period_range("1978-09","1999-08",freq="Q-AUG")
finance.index=per
finance.head()
# Out:
#          EARNINGS   EXPENSES
# 1979Q1  372572.16  122611.27
# 1979Q2  419440.58  133176.18
# 1979Q3  419766.49  154670.69
# 1979Q4  361453.31  209360.42
# 1980Q1  354463.33  174147.13

# %%
#5
website = pd.read_csv("website_traffic.csv")
enter = pd.to_datetime(website["ENTER"])
leave = pd.to_datetime(website["LEAVE"])

website["DURATION"] = leave-enter
website["DURATION"] = website["DURATION"].dt.total_seconds().astype(int)

enter_index = pd.to_datetime(website["ENTER"])
website.index = enter_index
website.drop("ENTER",axis=1)
website.index.names=['enter time']
minutes = website.resample("T")
m = minutes["DURATION"].mean()
hours=website.resample("H")
h=hours["DURATION"].mean()
plt.figure(figsize=(30,10))
ax1=h.plot(label='per hour')
ax2=m.plot(label='per minute')

ax1.legend(loc=1)
ax2.legend(loc=2)
plt.title("traffic")
plt.show()

# %%
# Part 7 
indianapolis = pd.read_csv("indianapolis.csv", index_col = 2)
miami = pd.read_csv("miami.csv", index_col = 2)
washingtondc = pd.read_csv("washingtondc.csv", index_col = 2)
chicago = pd.read_csv("chicago.csv", index_col = 2)
pittsburgh = pd.read_csv("pittsburgh.csv", index_col = 2)
cities = [indianapolis, miami, washingtondc, pittsburgh, chicago]

startDay = pd.to_datetime('1975-09-21').dayofyear

fig, ax = plt.subplots(figsize=(12,8))
for index, city in enumerate(cities):
    city.index = pd.to_datetime(city.index)
    city['DayNum'] = city.index.dayofyear
    
    city['DayNum'] = np.where(city['DayNum'] >= startDay, 
                                     city['DayNum'] - startDay + 1, 
                                     366 + city['DayNum'] - startDay)
    if index == 4:
        plt.scatter(city['DayNum'], city['TMAX'], c='#800000', linewidths=None, s=1/4, label = 'chicago-max')
        plt.scatter(city['DayNum'], city['TMIN'], c='#800000', linewidths=None, s=1/4, label= 'chicago-min')
        plt.legend()
    else:
        plt.scatter(city['DayNum'], city['TMAX'], c='black', linewidths=None, s=1/4, label = 'other-max')
        plt.scatter(city['DayNum'], city['TMIN'], c='black', linewidths=None, s=1/4,label = 'other-min')


born = (indianapolis.loc['1975-01-22','TMAX'] + indianapolis.loc['1975-01-22','TMIN']) / 2
league = (pittsburgh.loc['1988-07-14','TMAX'] + pittsburgh.loc['1988-07-14','TMIN']) / 2              
days = 366 + np.array([pd.to_datetime('1975-01-22').dayofyear, pd.to_datetime('1988-07-14').dayofyear]) - startDay
plt.plot(days, [born, league[0]], color='yellow', mec='black',  marker='o', ms=10, lw=0)           
plt.annotate('Born', xy=(days[0], born), xytext=(days[0], 90), 
                 arrowprops=dict(facecolor='black',shrink=0.05))
plt.annotate('Little League All-Star Team Wins Regional Championship', 
             xy=(days[1],league[0]), xytext=(days[1], 25), 
                 arrowprops=dict(facecolor='black',shrink=0.05))
plt.show()

# %%
# Part 8

# %%
lipids = pd.read_csv("lipids.csv", skiprows=4)
lipids = lipids[lipids['diseased'] == 1]
fig, ax = plt.subplots()
n, bins = plt.hist(lipids["chol"], bins=25)[0], plt.hist(lipids['chol'], bins = 25)[1]
plt.xlabel("chol")
plt.ylabel("freq")
plt.show()
chol = pd.cut(lipids["chol"], 25)
print(f"highest freq: { np.array([bins[n.argmax()], bins[n.argmax()+1]]).mean()}")
# Out:
# highest freq: 236.04000000000002

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(lipids['chol'], lipids['trig'], bins=25)

xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25)
xpos = xpos.flatten('F')
ypos = ypos.flatten('F')
zpos = np.zeros_like(xpos)

dx = 0.5 * np.ones_like(zpos)
dy = dx.copy()
dz = hist.flatten()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b')

ax.set_xlabel('chol')
ax.set_ylabel('tri')
ax.set_zlabel('Freq')

plt.title('Cholesterol vs. Triglicerides')
plt.show()

# %%
# Part 9
payems = pd.read_csv("payems.csv")
payems['PAYEMS'] = payems['PAYEMS'] * 1000
payems['DATE'] = pd.to_datetime(payems['DATE'])
payems.iloc[:358,0] = payems.iloc[:358,0] - pd.DateOffset(years=100)
payems = payems.set_index('DATE')
recStart = np.array(['2007-12-01', '2001-03-01', '1990-07-01', '1981-07-01', 
                           '1980-07-01', '1973-11-01', '1969-12-01', '1960-04-01',
                           '1957-08-01', '1953-07-01', '1948-11-01', '1945-02-01',
                           '1937-07-01', '1929-07-01'], dtype ='datetime64')

for i in range(9):
    payems = payems.append([payems.iloc[i]]*11)
payems = payems.sort_index(axis=0)

jobGrowth = np.empty((14,137))
startid = []

for i in range(12):
    startid.append(payems.index.get_loc(recStart[i]))
    
startid.append(100)
startid.append(12)


for ii in range(14):
    jobGrowth[ii] = list(payems.iloc[startid[ii]-12:startid[ii]+125, 0])
        
row_start = jobGrowth[:,0]
jobGrowth = jobGrowth / row_start[:,None]

fig, ax = plt.subplots(figsize = (10,10))
for ii in range(14):
    if ii == 0:
        plt.plot(jobGrowth[ii], 'r-', lw=4, label=recStart[ii])
    elif ii == 12:
        plt.plot(jobGrowth[ii], label='1937-05-01')
    elif ii == 13:
        plt.plot(jobGrowth[ii], 'k-', lw=4, label='1929-08-01')
    else:
        plt.plot(jobGrowth[ii], label=recStart[ii])
        
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel("Jobs vs peak")
plt.xlabel("time past since peak")
labels = ['-1yr', 'peak', '+1yr', '+2yr', '+3yr', '+4yr',
          '+5yr', '+6yr', '+7yr', '+8yr', '+9yr', '+10yr']
plt.xticks(np.arange(0, 145, 12), labels)

x = np.linspace(0, 145, 144)
ax.axhline(1, ls='--', linewidth=1.5, color='grey')
ax.axvline(12, ls='--', linewidth=1.5, color='grey')
plt.show()
